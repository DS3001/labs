# %% [markdown]
# # Web Scraping
#
# Last time, we looked at REST API's as a source of data. You can get lots of very high quality data this way.
#
# Some data is available online, but not through an API. When this is the case, some times you can simply copy and paste the data into a .csv file and go on with your life. But if there are many records to parse and combine into a dataset, that might be impossible. Can we automate the collection of data from online sources?
#
# This is called web scraping. Broadly speaking: Web scraping is legal, but what you plan to do with the results of your scraping might not be. In general, most sites do not want you to scrape them at this point, but there is not really a way to stop you if you are sufficiently motivated. Be careful to use server resources respectfully (not too many requests per unit time), think seriously about privacy concerns, and be careful who you share your work with.

# %% [markdown]
# We'll be scraping data about used cars in Charlottesville from Craigslist. This will give us a chance to put those wrangling, EDA, and visualization skills to work.
#
# We'll use the `requests` package, as we did with API's, but will be getting the kinds of web pages you see everyday. Again, we'll use a header with a user-agent that masks our true identity so that we're not rejected by the server. This particular url points to the car listings for Craigslist in Charlottesville.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import requests # Page requests

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'}
url = 'https://charlottesville.craigslist.org/search/cta?purveyor=owner#search=1~gallery~0~0'
raw = requests.get(url,headers=header) # Get page

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import requests

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'}
url = 'https://charlottesville.craigslist.org/search/msa?purveyor=owner#search=1~gallery~0~0'
instr = requests.get(url,headers=header)

# %% [markdown]
# Now that we have that particular page available locally, we want to **parse** it and get results from it. To do that, we can use a package called `beautifulSoup` or `bs4`.
#
# What does `beautifulSoup` do for us? Let's go to the web page of interest. You probably see something like this:
#
# ![Listings](craigslist.png "Craigslist")
#
# But if you "view page source" -- which is CTRL+U -- in Chrome, you see what the computer sees:
#
# ![Listings](craigslist_source.png "Craigslist")
#
# Since your web browser needs lots of instructions about how to render the text, pictures, and other content on your web page, there are a lot of clues about where the data live and how to extricate them from a page. These clues are called **tags**. If you wander the source for the search page on cars, you see a particular `class = "cl-static-search-result"` term appear attached to each listing:
#
# ![Listings](listing.png "Craigslist")
#
# This structure can be exploited to search the page for information. This kind of detective work -- looking at the page source, finding the interesting tages, and then searching the page with `beautifulSoup` -- is the basic job of web scraping.

# %% [markdown]
# ## 1. Pick something else on Craigslist: Musical instruments, roommates, antiques, etc. Look at the search page and its source code. Record which fields/data you would like to gather, and what kinds of EDA you'd do with it.

# %% [markdown]
# The following code chunk takes the raw content from `requests` and turns it into a beautifulSoup object, which can search the page and return results for us:

# %%
from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings

# %%
from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(instr.content,'html.parser') # Parse the html
instr_list = bsObj.find_all(class_="cl-static-search-result")

# %%
instr_list[0].find('div',class_='title').get_text()
# Out:
# 'Martin 2005 D35 Sunburst Acoustic'

# %%
instr_list[1].find('div', class_= 'price').get_text()
# Out:
# '$45'

# %% [markdown]
# Why is the argument `class_` and not just `class`? The word `class` is a reserved keyword for Python, and cannot be used by anyone else, similar to `True` and `False`. But since we want the `class = "cl-static-search-result"` terms, we need to use the `class_` argument to the `.find_all` method.
#
# The `.find_all` function dredges the entire page and finds all the instances of `class = "cl-static-search-result"`, resulting in a list of entries. We can then parse the entries.
#
# For each listing, we'll use the `.find` method to search within the listing record for specific information. To get the information we want, we can then use `.get_text()`.
#
# In the code below, two more things happen.
#
# First, I would like to get the brand of the car from the post title, if possible. To do this, I split the title into words using `title.split()`, and then I use a list comprehension to look over every word in the title and check whether it appears in the `brands` list.
#
# Second, I would like to get the year the car was built, so I can determine the vehicle's age. To do this, I use a thing called **regular expressions** that provides a language for expressing patterns. Do I remember how to do this off the top of my head? No, I read a few pages in a book and looked on StackOverflow for answers. Roughly, in order to express the idea "any year starting with 20xx," you can write `20[0-9][0-9]`, and for "any year starting with 19xx," you can write `19[0-9][0-9]`. The `[0-9]`'s act as wildcards for any digit. This allows me to use the `re` package to find any instances of year-like numbers in the title text, using `re.search(r'20[0-9][0-9]|19[0-9][0-9]', title )`.
#
# This is all nested in a for-loop over the listings, and the data is appended to a list.

# %%
import re # Regular expressions

brands = ['honda', 'dodge','toyota','ford','tesla','gmc','jeep','bmw','mitsubishi','mazda',
          'volvo','audi','volkswagen','chevy','chevrolet','acura','kia','subaru','lexus',
          'cadillac','buick','porsche','infiniti']

data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title.split()
    hits = [word for word in words if word in brands] # Find brands in the title
    if len(hits) == 0:
        brand = 'missing'
    else:
        brand = hits[0]
    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)
    #
    data.append({'title':title,'price':price,'year':year,'link':link,'brand':brand})

# %%
data
# Out:
# [{'title': 'martin 2005 d35 sunburst acoustic',
#   'price': '$2,800',
#   'year': '2005',
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-martin-2005-d35/7780483373.html',
#   'brand': 'missing'},
#  {'title': 'crate amp, made in usa, exc cond, lightweight, powerful',
#   'price': '$45',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/crozet-crate-amp-made-in-usa-exc-cond/7777810904.html',
#   'brand': 'missing'},
#  {'title': 'pa amp for parts or repair, with case, free',
#   'price': '$1',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/crozet-pa-amp-for-parts-or-repair-with/7783477517.html',
#   'brand': 'missing'},
#  {'title': 'martin standard d-18',
#   'price': '$1,895',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/palmyra-martin-standard-18/7780232849.html',
#   'brand': 'missing'},
#  {'title': 'lot of 3 guitars',
#   'price': '$300',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/orange-lot-of-guitars/7785585854.html',
#   'brand': 'missing'},
#  {'title': 'esp ltd m-1000 ebony',
#   'price': '$800',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/culpeper-esp-ltd-1000-ebony/7785553274.html',
#   'brand': 'missing'},
#  {'title': 'slide guitar package (instructionals, slides, capos)',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-slide-guitar-package/7779300850.html',
#   'brand': 'missing'},
#  {'title': 'keyboard',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-keyboard/7785343751.html',
#   'brand': 'missing'},
#  {'title': '2023 prs 594 mccarty',
#   'price': '$3,299',
#   'year': '2023',
#   'link': 'https://charlottesville.craigslist.org/msg/d/forest-2023-prs-594-mccarty/7785287052.html',
#   'brand': 'missing'},
#  {'title': '5f1 tweed champ, 12" cabinet, celestion speaker',
#   'price': '$750',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-5f1-tweed-champ-12/7785262353.html',
#   'brand': 'missing'},
#  {'title': '5 string fender banjo/hardcase',
#   'price': '$1,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/troy-string-fender-banjo-hardcase/7779055809.html',
#   'brand': 'missing'},
#  {'title': 'vox ac15hw1x w/ alnico blue',
#   'price': '$1,300',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/crozet-vox-ac15hw1x-alnico-blue/7781451791.html',
#   'brand': 'missing'},
#  {'title': 'harmony h415',
#   'price': '$850',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/waynesboro-harmony-h415/7784973554.html',
#   'brand': 'missing'},
#  {'title': 'adm 5 string banjo',
#   'price': '$185',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/waynesboro-adm-string-banjo/7784961984.html',
#   'brand': 'missing'},
#  {'title': 'ehx holy grail nano',
#   'price': '$80',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-ehx-holy-grail-nano/7784942080.html',
#   'brand': 'missing'},
#  {'title': 'yamaha piano key cover',
#   'price': '$15',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/troy-yamaha-piano-key-cover/7784764787.html',
#   'brand': 'missing'},
#  {'title': 'antique piano',
#   'price': '$0',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-antique-piano/7784720426.html',
#   'brand': 'missing'},
#  {'title': 'vintage yamaha 112 guitar amp spring reverb',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/glen-allen-vintage-yamaha-112-guitar/7778102801.html',
#   'brand': 'missing'},
#  {'title': 'violin for lefty 1/2 size',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-violin-for-lefty-2-size/7784686737.html',
#   'brand': 'missing'},
#  {'title': 'michael kelly mod shop 67 solid body electric guitar',
#   'price': '$700',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/shipman-michael-kelly-mod-shop-67-solid/7784649859.html',
#   'brand': 'missing'},
#  {'title': 'fender deluxe molded bass case',
#   'price': '$175',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-fender-deluxe-molded/7784591706.html',
#   'brand': 'missing'},
#  {'title': 'vincent bach mercedes trombone',
#   'price': '$350',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/waynesboro-vincent-bach-mercedes/7775501781.html',
#   'brand': 'missing'},
#  {'title': 'takamine eg341sc acoustic/electric guitar',
#   'price': '$300',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/staunton-takamine-eg341sc-acoustic/7784453075.html',
#   'brand': 'missing'},
#  {'title': 'baby taylor koa bte acoustic/electric',
#   'price': '$500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/staunton-baby-taylor-koa-bte-acoustic/7784445262.html',
#   'brand': 'missing'},
#  {'title': 'full size violin',
#   'price': '$300',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-full-size-violin/7784369148.html',
#   'brand': 'missing'},
#  {'title': 'usa peavey bandit transtube spring reverb amp',
#   'price': '$200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/glen-allen-usa-peavey-bandit-transtube/7782303721.html',
#   'brand': 'missing'},
#  {'title': 'fender fm 25r amp spring reverb',
#   'price': '$160',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/glen-allen-fender-fm-25r-amp-spring/7779352121.html',
#   'brand': 'missing'},
#  {'title': '1980 mxr m102 dyna comp with ross mod and added 9v jack',
#   'price': '$135',
#   'year': '1980',
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-1980-mxr-m102-dyna-comp/7784355887.html',
#   'brand': 'missing'},
#  {'title': 'vintage music song books',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/troy-vintage-music-song-books/7775988635.html',
#   'brand': 'missing'},
#  {'title': 'guitar pedal repair and restoration',
#   'price': '$0',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-guitar-pedal-repair-and/7784356851.html',
#   'brand': 'missing'},
#  {'title': '1979 mu-tron iii envelope filter',
#   'price': '$895',
#   'year': '1979',
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-1979-mu-tron-iii/7784355037.html',
#   'brand': 'missing'},
#  {'title': "early 70's univox u-1095 superfuzz",
#   'price': '$950',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-early-70s-univox-1095/7784356221.html',
#   'brand': 'missing'},
#  {'title': "1978 mxr distortion +, script box, with 9v jack and pete's tweaks",
#   'price': '$125',
#   'year': '1978',
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-1978-mxr-distortion-box/7784355960.html',
#   'brand': 'missing'},
#  {'title': '1983 dod 565-a stereo chorus pedal with 18v jack mod',
#   'price': '$85',
#   'year': '1983',
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-1983-dod-565-stereo/7784355830.html',
#   'brand': 'missing'},
#  {'title': 'cornet/trumpet: ready for band class!',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-cornet-trumpet-ready/7784301598.html',
#   'brand': 'missing'},
#  {'title': 'seymour duncan guitar pickups',
#   'price': '$60',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-seymour-duncan-guitar/7784078975.html',
#   'brand': 'missing'},
#  {'title': 'leather jacket - xl - rock on!!!',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/staunton-leather-jacket-xl-rock-on/7784073110.html',
#   'brand': 'missing'},
#  {'title': 'hand pan hang drum   symphonic steel',
#   'price': '$6,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-hand-pan-hang-drum/7776563784.html',
#   'brand': 'missing'},
#  {'title': 'yamaha stagepas 600i pa system',
#   'price': '$400',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-yamaha-stagepas-600i-pa/7778730251.html',
#   'brand': 'missing'},
#  {'title': '12.5" splash cymbal with mounting hardware',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/crozet-125-splash-cymbal-with-mounting/7774667228.html',
#   'brand': 'missing'},
#  {'title': 'beatle guitars',
#   'price': '$600',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/roanoke-beatle-guitars/7782860477.html',
#   'brand': 'missing'},
#  {'title': 'epiphone "worn" casino',
#   'price': '$400',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/staunton-epiphone-worn-casino/7782641687.html',
#   'brand': 'missing'},
#  {'title': 'epiphone "inspired by" les paul custom',
#   'price': '$1,075',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/staunton-epiphone-inspired-by-les-paul/7782588710.html',
#   'brand': 'missing'},
#  {'title': 'gretsch g5622t electromatic guitar w/bigsby',
#   'price': '$500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-gretsch-g5622t/7783201045.html',
#   'brand': 'missing'},
#  {'title': 'epiphone "inspired by" 355 guitar',
#   'price': '$899',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/staunton-epiphone-inspired-by-355-guitar/7782587985.html',
#   'brand': 'missing'},
#  {'title': 'snarling dogs spd6 effect pedal',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/palmyra-snarling-dogs-spd6-effect-pedal/7783158000.html',
#   'brand': 'missing'},
#  {'title': 't-rex yellow drive',
#   'price': '$80',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/palmyra-rex-yellow-drive/7783152931.html',
#   'brand': 'missing'},
#  {'title': 'groove tube 6v6r',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/palmyra-groove-tube-6v6r/7783149543.html',
#   'brand': 'missing'},
#  {'title': 'relicked telecaster copy',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/palmyra-relicked-telecaster-copy/7774575718.html',
#   'brand': 'missing'},
#  {'title': 'fender pickups',
#   'price': '$1',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/palmyra-fender-pickups/7783143917.html',
#   'brand': 'missing'},
#  {'title': 'custom crowder guitar hd-28',
#   'price': '$2,900',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/louisa-custom-crowder-guitar-hd-28/7783055254.html',
#   'brand': 'missing'},
#  {'title': '2023 suhr modern plus guitar',
#   'price': '$3,299',
#   'year': '2023',
#   'link': 'https://charlottesville.craigslist.org/msg/d/forest-2023-suhr-modern-plus-guitar/7782902459.html',
#   'brand': 'missing'},
#  {'title': 'looking for broken or unwanted musical instruments',
#   'price': '$1',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/crozet-looking-for-broken-or-unwanted/7782866190.html',
#   'brand': 'missing'},
#  {'title': 'reduced: dimarzio paf classic humbuckers - nickel',
#   'price': '$130',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-reduced-dimarzio-paf/7782824822.html',
#   'brand': 'missing'},
#  {'title': 'reduced: fender tex-mex stratocaster pickup set',
#   'price': '$85',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-reduced-fender-tex-mex/7782824772.html',
#   'brand': 'missing'},
#  {'title': 'danelectro daddy-o',
#   'price': '$75',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-danelectro-daddy/7782824720.html',
#   'brand': 'missing'},
#  {'title': 'looper',
#   'price': '$25',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-looper/7782824684.html',
#   'brand': 'missing'},
#  {'title': 'fender hot rod deluxe - made in usa w/ upgraded tubes & mods',
#   'price': '$200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-fender-hot-rod-deluxe/7774974514.html',
#   'brand': 'missing'},
#  {'title': 'tonette musical instrument',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/palmyra-tonette-musical-instrument/7776915887.html',
#   'brand': 'missing'},
#  {'title': 'bobelock luxurious professional suspension viola case',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/scottsville-bobelock-luxurious/7776656248.html',
#   'brand': 'missing'},
#  {'title': '4 fake books for  c instruments',
#   'price': '$60',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-fake-books-for/7781864992.html',
#   'brand': 'missing'},
#  {'title': "2023 gibson 50's les paul standard goldtop",
#   'price': '$2,499',
#   'year': '2023',
#   'link': 'https://charlottesville.craigslist.org/msg/d/forest-2023-gibson-50s-les-paul/7781834742.html',
#   'brand': 'missing'},
#  {'title': 'sire larry carlton a3-d dreadnought',
#   'price': '$325',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/staunton-sire-larry-carlton-a3/7781791310.html',
#   'brand': 'missing'},
#  {'title': 'ormsby goliath 7 string moore green',
#   'price': '$1,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-ormsby-goliath-string/7781732792.html',
#   'brand': 'missing'},
#  {'title': 'left-handed 5-string banjo',
#   'price': '$425',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-left-handed-string-banjo/7781713588.html',
#   'brand': 'missing'},
#  {'title': 'schecter diamond series c-1 electric guitar',
#   'price': '$225',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-schecter-diamond-series/7781549748.html',
#   'brand': 'missing'},
#  {'title': 'katana mk2 100, 1-12,w footswitch',
#   'price': '$325',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-katana-mk-footswitch/7781393402.html',
#   'brand': 'missing'},
#  {'title': 'skb ps-25 pedalboard with carrying case',
#   'price': '$75',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-skb-ps-25-pedalboard/7781342577.html',
#   'brand': 'missing'},
#  {'title': 'fender rocpro 1000 guitar head',
#   'price': '$200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/quinque-fender-rocpro-1000-guitar-head/7781267582.html',
#   'brand': 'missing'},
#  {'title': 'wanted: older arch top guitar',
#   'price': '$1',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-wanted-older-arch-top/7780003467.html',
#   'brand': 'missing'},
#  {'title': 'rockbridge custom guitar',
#   'price': '$4,800',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-rockbridge-custom-guitar/7777904375.html',
#   'brand': 'missing'},
#  {'title': 'halfstack line6 hd100 and hd100 mkii bogner guitar amps',
#   'price': '$250',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/quinque-halfstack-line6-hd100-and-hd100/7781008646.html',
#   'brand': 'missing'},
#  {'title': 'simmons electric drum set',
#   'price': '$175',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-simmons-electric-drum/7780940394.html',
#   'brand': 'missing'},
#  {'title': 'reverend warhawk da electric guitar in midnight black with reverend tw',
#   'price': '$850',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/staunton-reverend-warhawk-da-electric/7780903992.html',
#   'brand': 'missing'},
#  {'title': 'reverend mat west model',
#   'price': '$700',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/staunton-reverend-mat-west-model/7779529608.html',
#   'brand': 'missing'},
#  {'title': 'warmoth jaguar',
#   'price': '$900',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/staunton-warmoth-jaguar/7779368959.html',
#   'brand': 'missing'},
#  {'title': 'miraphone 186 4v rotary bb tuba',
#   'price': '$3,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-miraphone-186-4v-rotary/7780585070.html',
#   'brand': 'missing'},
#  {'title': 'bach tr600h2 trumpet',
#   'price': '$500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-bach-tr600h2-trumpet/7780582376.html',
#   'brand': 'missing'},
#  {'title': 'open back harmony banjo',
#   'price': '$125',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/ruckersville-open-back-harmony-banjo/7780538568.html',
#   'brand': 'missing'},
#  {'title': '1940s hammond solovox 3 octave keyboard and tone box',
#   'price': '$115',
#   'year': '1940',
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-1940s-hammond-solovox/7772274029.html',
#   'brand': 'missing'},
#  {'title': 'magnatone twilighter mono',
#   'price': '$2,400',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-magnatone-twilighter/7780321446.html',
#   'brand': 'missing'},
#  {'title': '‘68 custom pro reverb',
#   'price': '$950',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-68-custom-pro-reverb/7780261987.html',
#   'brand': 'missing'},
#  {'title': 'stratocaster with gig bag cord amp',
#   'price': '$120',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/schuyler-stratocaster-with-gig-bag-cord/7772930257.html',
#   'brand': 'missing'},
#  {'title': 'gretsch g5410t electromatic “rat rod” hollowbody electric guitar',
#   'price': '$575',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/crozet-gretsch-g5410t-electromatic-rat/7772402351.html',
#   'brand': 'missing'},
#  {'title': 'blackstar id:core stereo100 guitar amp w ftswitch for built in looper',
#   'price': '$225',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/crozet-blackstar-idcore-stereo100/7774265088.html',
#   'brand': 'missing'},
#  {'title': 'vintage yamaha fg-340 acoustic electric guitar',
#   'price': '$300',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/crozet-vintage-yamaha-fg-340-acoustic/7773988505.html',
#   'brand': 'missing'},
#  {'title': 'awesome! hughes & kettner era1 250w acoustic guitar amp w softcover',
#   'price': '$650',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/crozet-awesome-hughes-kettner-era1-250w/7771723951.html',
#   'brand': 'missing'},
#  {'title': '‘03 larrivee d-03r acoustic guitar w hsc',
#   'price': '$1,100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/crozet-03-larrivee-03r-acoustic-guitar/7773578714.html',
#   'brand': 'missing'},
#  {'title': 'ampeg bass amp vintage svt iii',
#   'price': '$400',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/raphine-ampeg-bass-amp-vintage-svt-iii/7779642101.html',
#   'brand': 'missing'},
#  {'title': 'yamaha 30w combo amp accutronics reverb',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/glen-allen-yamaha-30w-combo-amp/7774424876.html',
#   'brand': 'missing'},
#  {'title': 'peavey stereo chorus 400 guitar amplifier',
#   'price': '$240',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/waynesboro-peavey-stereo-chorus-400/7779548704.html',
#   'brand': 'missing'},
#  {'title': 'fender mustang ii 40w guitar amplifier',
#   'price': '$115',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/waynesboro-fender-mustang-ii-40w-guitar/7779545072.html',
#   'brand': 'missing'},
#  {'title': 'ukelele package',
#   'price': '$130',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-ukelele-package/7779339146.html',
#   'brand': 'missing'},
#  {'title': 'rare early model kramer pacer (1985)',
#   'price': '$999',
#   'year': '1985',
#   'link': 'https://charlottesville.craigslist.org/msg/d/amherst-rare-early-model-kramer-pacer/7775042571.html',
#   'brand': 'missing'},
#  {'title': 'tone dexter acoustic preamp v1',
#   'price': '$300',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/amherst-tone-dexter-acoustic-preamp-v1/7775053609.html',
#   'brand': 'missing'},
#  {'title': 'digitech harmony man pedal - reduced!',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/amherst-digitech-harmony-man-pedal/7775054274.html',
#   'brand': 'missing'},
#  {'title': 'wampler pinnacle standard distortion pedal',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/amherst-wampler-pinnacle-standard/7775055007.html',
#   'brand': 'missing'},
#  {'title': 'celestion v30 g12 speaker',
#   'price': '$85',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/amherst-celestion-v30-g12-speaker/7775057629.html',
#   'brand': 'missing'},
#  {'title': 'earthquaker devices space spiral effects pedal',
#   'price': '$125',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-earthquaker-devices/7775029147.html',
#   'brand': 'missing'},
#  {'title': 'fender limited edition telecaster',
#   'price': '$650',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/lynchburg-fender-limited-edition/7778415585.html',
#   'brand': 'missing'},
#  {'title': 'skb ps-25 pedalboard with carrying case',
#   'price': '$75',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-skb-ps-25-pedalboard/7769898956.html',
#   'brand': 'missing'},
#  {'title': 'fender limited edition telecaster',
#   'price': '$650',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/lynchburg-fender-limited-edition/7778215113.html',
#   'brand': 'missing'},
#  {'title': 'otto ernst fischer violin',
#   'price': '$1,800',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-otto-ernst-fischer/7768638949.html',
#   'brand': 'missing'},
#  {'title': 'ibanez sa260 flametop- offers?!?',
#   'price': '$1',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-ibanez-sa260-flametop/7768982733.html',
#   'brand': 'missing'},
#  {'title': 'bow re-hair',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/bow-re-hair/7777281604.html',
#   'brand': 'missing'},
#  {'title': 'steinway model m grand piano for sale',
#   'price': '$4,950',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/amherst-steinway-model-grand-piano-for/7777250716.html',
#   'brand': 'missing'},
#  {'title': 'prs mccarty korina with humbuckers 2008 - 2009 - vintage cherry',
#   'price': '$3,400',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-prs-mccarty-korina-with/7777031896.html',
#   'brand': 'missing'},
#  {'title': 'prs custom 24 wood library 10-top',
#   'price': '$3,800',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-prs-custom-24-wood/7777027410.html',
#   'brand': 'missing'},
#  {'title': 'fender frontman 15r amp',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/etlan-fender-frontman-15r-amp/7776886302.html',
#   'brand': 'missing'},
#  {'title': 'patch cables, effects box connectors, and adapters',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-patch-cables-effects/7767863277.html',
#   'brand': 'missing'},
#  {'title': 'peavey cs 800x4 power amp',
#   'price': '$300',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/quinque-peavey-cs-800x4-power-amp/7776691338.html',
#   'brand': 'missing'},
#  {'title': 'peavey sp 115m floor monitors (4)',
#   'price': '$680',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/quinque-peavey-sp-115m-floor-monitors/7776684766.html',
#   'brand': 'missing'},
#  {'title': 'peavey cs 800s 2-channel power amp',
#   'price': '$220',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/quinque-peavey-cs-800s-channel-power-amp/7776675175.html',
#   'brand': 'missing'},
#  {'title': 'free upright piano!',
#   'price': '$1',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-free-upright-piano/7773265254.html',
#   'brand': 'missing'},
#  {'title': 'peavey dm 118 subs (pair)',
#   'price': '$1,300',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/quinque-peavey-dm-118-subs-pair/7776658168.html',
#   'brand': 'missing'},
#  {'title': 'yamaha stagepas300 pa system',
#   'price': '$285',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/waynesboro-yamaha-stagepas300-pa-system/7776462638.html',
#   'brand': 'missing'},
#  {'title': 'line 6 powercab 112',
#   'price': '$600',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/keswick-line-powercab-112/7776276382.html',
#   'brand': 'missing'},
#  {'title': 'fender custom shop 1958 reissue stratocaster',
#   'price': '$5,900',
#   'year': '1958',
#   'link': 'https://charlottesville.craigslist.org/msg/d/earlysville-fender-custom-shop-1958/7776086657.html',
#   'brand': 'missing'},
#  {'title': 'tascam porta studio cassette 4 track',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/schuyler-tascam-porta-studio-cassette/7776064020.html',
#   'brand': 'missing'},
#  {'title': '2008 fender telecaster customized',
#   'price': '$550',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/msg/d/swoope-2008-fender-telecaster-customized/7768699725.html',
#   'brand': 'missing'},
#  {'title': 'old record albums',
#   'price': '$5',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/troy-old-record-albums/7767802895.html',
#   'brand': 'missing'},
#  {'title': 'lights for sale',
#   'price': '$200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/brightwood-lights-for-sale/7775851712.html',
#   'brand': 'missing'},
#  {'title': 'roland edirol pcr-800 midi controller',
#   'price': '$250',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/earlysville-roland-edirol-pcr-800-midi/7775257801.html',
#   'brand': 'missing'},
#  {'title': 'pearl p-120p drum pedal',
#   'price': '$35',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/earlysville-pearl-120p-drum-pedal/7775256673.html',
#   'brand': 'missing'},
#  {'title': 'want - guitar body / bass neck / broken or unwanted stuff',
#   'price': '$1',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-want-guitar-body-bass/7771684212.html',
#   'brand': 'missing'},
#  {'title': 'behringer ultragraph pro fbq3102 31 band stereo graphics eq w/fbq',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-behringer-ultragraph/7774802257.html',
#   'brand': 'missing'},
#  {'title': 'new rack mount 234xl crossover frequency divider equalizer will ship',
#   'price': '$70',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-new-rack-mount-234xl/7774799677.html',
#   'brand': 'missing'},
#  {'title': 'heritage h-150 standard',
#   'price': '$1,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/keswick-heritage-150-standard/7766362121.html',
#   'brand': 'missing'},
#  {'title': 'live wire universal footswitch for guitar amps',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/crozet-live-wire-universal-footswitch/7766628972.html',
#   'brand': 'missing'},
#  {'title': 'casio cdp 120 keyboard',
#   'price': '$280',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/crozet-casio-cdp-120-keyboard/7774581894.html',
#   'brand': 'missing'},
#  {'title': 'turnkey pa equipment ** reduced **',
#   'price': '$800',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/palmyra-turnkey-pa-equipment-reduced/7774331609.html',
#   'brand': 'missing'},
#  {'title': 'ios/usb microphone',
#   'price': '$75',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/quinque-ios-usb-microphone/7774229521.html',
#   'brand': 'missing'},
#  {'title': 'music stands / dj stands / laptop stands',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-music-stands-dj-stands/7765417756.html',
#   'brand': 'missing'},
#  {'title': 'antique 1924 gibson mandolin a2-z',
#   'price': '$5,000',
#   'year': '1924',
#   'link': 'https://charlottesville.craigslist.org/msg/d/centreville-antique-1924-gibson/7773999225.html',
#   'brand': 'missing'},
#  {'title': 'pa for band',
#   'price': '$650',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/waynesboro-pa-for-band/7773710147.html',
#   'brand': 'missing'},
#  {'title': 'antique indian tanpura/tamboura drone instrument',
#   'price': '$500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/shipman-antique-indian-tanpura-tamboura/7773705097.html',
#   'brand': 'missing'},
#  {'title': 'upright bass stands',
#   'price': '$15',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/louisa-upright-bass-stands/7773512380.html',
#   'brand': 'missing'},
#  {'title': 'large packhorse mixer case (custom built)',
#   'price': '$750',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/buena-vista-large-packhorse-mixer-case/7773000779.html',
#   'brand': 'missing'},
#  {'title': 'acoustic guitar real solid wood',
#   'price': '$140',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/schuyler-acoustic-guitar-real-solid-wood/7772941867.html',
#   'brand': 'missing'},
#  {'title': 'strat style yamaha pacifica guitar',
#   'price': '$140',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/schuyler-strat-style-yamaha-pacifica/7772933684.html',
#   'brand': 'missing'},
#  {'title': 'presonus audiobox usb 96 anniversary ed.',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/orange-presonus-audiobox-usb-96/7763878759.html',
#   'brand': 'missing'},
#  {'title': 'yamaha gh1 grand piano sn# 3040007',
#   'price': '$4,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/lynchburg-yamaha-gh1-grand-piano-sn/7772527299.html',
#   'brand': 'missing'},
#  {'title': 'fake book ( over1,200 songs)',
#   'price': '$15',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/charlottesville-fake-book-over1200-songs/7772379453.html',
#   'brand': 'missing'},
#  {'title': 'wurlitzer upright piano',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/msg/d/waynesboro-wurlitzer-upright-piano/7772325543.html',
#   'brand': 'missing'}]

# %% [markdown]
# ## 2. Get your search results of interest and extract data from them, using code similar to what's above.

# %% [markdown]
# With the data scraped from Craigslist, we can put it in a dataframe and wrangle it. Of course, price and year come in as text, not numbers, and need to be typecast/coerced:

# %%
## Wrangle the data
df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['year'] = pd.to_numeric(df['year'],errors='coerce')
df['age'] = 2025-df['year']
print(df.shape)
df.to_csv('craigslist_cville_cars.csv') # Save data in case of a disaster
df.head()
# Out:
# (144, 6)
#                                                title  price    year  \
# 0                  martin 2005 d35 sunburst acoustic   2800  2005.0
# 1  crate amp, made in usa, exc cond, lightweight,...     45     NaN
# 2        pa amp for parts or repair, with case, free      1     NaN
# 3                               martin standard d-18   1895     NaN
# 4                                   lot of 3 guitars    300     NaN
#
#                                                 link    brand   age
# 0  https://charlottesville.craigslist.org/msg/d/c...  missing  20.0
# 1  https://charlottesville.craigslist.org/msg/d/c...  missing   NaN
# 2  https://charlottesville.craigslist.org/msg/d/c...  missing   NaN
# 3  https://charlottesville.craigslist.org/msg/d/p...  missing   NaN
# 4  https://charlottesville.craigslist.org/msg/d/o...  missing   NaN

# %% [markdown]
# With the data in and wrangled, we can now do EDA:

# %%
# EDA for price and age:
print(df['price'].describe())
df['price'].hist(grid=False)
plt.show()
print(df['age'].describe())
df['age'].hist(grid=False)
plt.show()

# %%
# Price by brand:
df.loc[:,['price','brand']].groupby('brand').describe()

# %%
# Age by brand:
df.loc[:,['age','brand']].groupby('brand').describe()

# %%
ax = sns.scatterplot(data=df, x='age', y='price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
df['log_price'] = np.log(df['price'])
df['log_age'] = np.log(df['age'])

ax = sns.scatterplot(data=df, x='log_age', y='log_price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

print(df.loc[:,['log_price','log_age']].cov())
print(df.loc[:,['log_price','log_age']].corr())

# %%
sns.jointplot(data=df, x='log_age', y='log_price',kind='hex')

# %% [markdown]
# ## 3. Wrangle your data, do some EDA, and make some plots. Try to find some interesting relationships or stories to tell about your data.

# %% [markdown]
# The final thing we want to do is go from scraping a single page to crawling around.
#
# The idea here is that every web page is connected to some other page. By extracting links as we move from page to page, we can create a web crawler that wanders around for us, gathering information of interest.
#
# In this case, we want to use the search results to then visit each individual page for each listing. Since we saved the links to the web pages in the previous scrape, we can now simply for-loop over that column in the dataframe, visiting the page listing for each of the cars in the search results:

# %%
import time # Time delays
import random # Random numbers

links = df['link']
data = []
for link in links: # about 3 minutes
    time.sleep(random.randint(1, 3)) # Random delays
    raw = requests.get(link,headers=header) # Get page
    bsObj = soup(raw.content,'html.parser') # Parse the html
    #
    try:
        year_post = bsObj.find(class_='attr important').find(class_ = 'valu year').get_text()
    except:
        year_post = np.nan
    #
    try:
        condition = bsObj.find(class_='attr condition').find(href=True).get_text()
    except:
        condition = 'missing'
    #
    try:
        cylinders = bsObj.find(class_='attr auto_cylinders').find(class_ = 'valu').get_text()
        cylinders = cylinders.replace('\n','')
    except:
        cylinders = 'missing'
    #
    try:
        drivetrain = bsObj.find(class_='attr auto_drivetrain').find(href=True).get_text()
    except:
        drivetrain = 'missing'
    #
    try:
        fuel = bsObj.find(class_='attr auto_fuel_type').find(href = True).get_text()
    except:
        fuel = 'missing'
    #
    try:
        miles = bsObj.find(class_='attr auto_miles').find(class_ = 'valu').get_text()
    except:
        miles = np.nan
    #
    try:
        color = bsObj.find(class_='attr auto_paint').find(href=True).get_text()
    except:
        color='missing'
    #
    try:
        title = bsObj.find(class_='attr auto_title_status').find(href=True).get_text()
    except:
        title='missing'
    #
    try:
        transmission = bsObj.find(class_='attr auto_transmission').find(href=True).get_text()
    except:
        transmission = 'missing'
    #
    try:
        bodytype = bsObj.find(class_='attr auto_bodytype').find(href=True).get_text()
    except:
        bodytype = 'missing'
    #
    text = bsObj.find(id='postingbody').get_text()
    text = text.replace('\n','')
    text = text.replace('QR Code Link to This Post','')
    record = {'title':title,
              'year_post':year_post,
              'condition':condition,
              'cylinders':cylinders,
              'drivetrain':drivetrain,
              'fuel':fuel,
              'miles':miles,
              'color':color,
              'title':'title',
              'transmission':transmission,
              'bodytype':bodytype,
              'text':text,}
    data.append(record)

# %% [markdown]
# What are the new features here?
#
# First, we don't want to overwhelm the servers, so we put a small delay between each request of a listing, `time.sleep(random.randint(1, 3))`. This waits a random amount of time between 1 and 3 seconds to avoid overwhelming their server.
#
# Second, we use the try/except block. This is a useful control structure in general, but especially for web scraping. Python tries the statements under `try:`, and if it fails, executes the steps under `except:`. This can happen, in this case, with missing data, which crashes the crawler. Instead, we put our missing codes into our dataframe right away.
#
# Third, we used `.find().find().get_text()` to find the data we're looking for. In general, the structure of mark-up langauges like HTML and XML makes it possible to "drill down" into their entries and extract the information of interest. This exploitation of mark-up languages could be the subject of a whole course on procuring data from the web.

# %% [markdown]
# With the data scraped, we can make a new dataframe, combine it with the old one using `pd.concat`, and do some wrangling to clean the data up:

# %%
new_df = pd.DataFrame.from_dict(data)
new_df.head()

df = pd.concat([df,new_df],axis=1) # combine data frames
df.head()

df['miles'] = df['miles'].str.replace(',','')
df['miles'] = pd.to_numeric(df['miles'],errors='coerce')

df['year_post'] = df['year_post'].str.replace(',','')
df['year_post'] = pd.to_numeric(df['year_post'],errors='coerce')
df.to_csv('craiglist_cville_cars_long.csv')

# %% [markdown]
# ## 4. From your search results, crawl to the links and extract more information about every listing in your original dataframe. Wrangle and do some EDA.
